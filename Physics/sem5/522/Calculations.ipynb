# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['text.usetex'] = True
Theta  = np.array([2574 , 2554 , 2484 , 2476 , 2440 , 2422 , 2418 , 2380 , 2372 , 2352 , 2342 , 2328 , 2308 , 2286 , 2276 , 2256 , 2246 , 2220 , 2200 , 2186 , 2156 , 2142 , 1884 , 1842 , 1834 , 2544 , 2318 , 2114 , 2104 , 1930 , 1488 , 838])
Lambda = np.array([7032 , 6929 , 6717 , 6678 , 6599 , 6533 , 6507 , 6402 , 6383 , 6334 , 6305 , 6267 , 6217 , 6164 , 6143 , 6096 , 6074 , 6030 , 5976 , 5945 , 5882 , 5852 , 5401 , 5341 , 5331 , 6907 , 6234 , 5791 , 5770 , 5461 , 4916 , 4047])

plt.figure(figsize=[12, 5], dpi=100)

plt.plot(Theta, Lambda, 'b.')
plt.axvline(x = 2444, color = 'r')
plt.axvline(x = 1456, color = 'b')
plt.axvline(x = 814, color = 'm')

plt.xlabel("\Large $ \Theta, deg $")
plt.ylabel("\Large $ \lambda, \, $ \AA")
plt.title("\Large Spectrum graduation")
plt.grid()

plt.show()
