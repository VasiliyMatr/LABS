# %%
from pylab import figure, cm

import matplotlib.pyplot as plt
import numpy as np

t_min = 0
t_max = 5
x_min = 0
x_max = 5

data = np.loadtxt('sol.txt', ndmin=2)

plt.imshow(data,extent=[x_min,x_max,t_min,t_max], cmap=cm.jet, origin='lower')
plt.colorbar()
plt.title("Transfer equation solution" , fontsize=8)
plt.savefig("sol.png", bbox_inches='tight')
plt.show()

data
# Out:
# array([[ 1.      ,  1.      ,  1.      , ...,  1.99988 ,  1.99991 ,
#          1.99994 ],
#        [ 1.99997 ,  1.99998 ,  1.99999 , ...,  0.951842,  0.956832,
#          0.961825],
#        [ 0.966821,  0.971819,  0.976821, ...,  1.99528 ,  1.99598 ,
#          1.99663 ],
#        ...,
#        [ 6.59676 ,  6.60104 ,  6.60531 , ..., 10.9198  , 10.9226  ,
#         10.9253  ],
#        [10.9253  , 10.9281  , 10.9308  , ..., 13.5087  , 13.51    ,
#         13.5114  ],
#        [13.5114  , 13.5128  , 13.5142  , ..., 14.381   , 14.381   ,
#         14.381   ]])
